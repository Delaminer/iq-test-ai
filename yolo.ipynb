# %%
# %pip install opencv-python torch torchvision pandas ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /home/alex/.local/lib/python3.11/site-packages (4.9.0.80)
# Requirement already satisfied: torch in /home/alex/.local/lib/python3.11/site-packages (2.2.0)
# Requirement already satisfied: torchvision in /home/alex/.local/lib/python3.11/site-packages (0.17.0)
# Requirement already satisfied: pandas in /home/alex/.local/lib/python3.11/site-packages (2.2.0)
# Requirement already satisfied: ultralytics in /home/alex/.local/lib/python3.11/site-packages (8.1.14)
# Requirement already satisfied: numpy>=1.21.2 in /home/alex/.local/lib/python3.11/site-packages (from opencv-python) (1.26.3)
# Requirement already satisfied: filelock in /home/alex/.local/lib/python3.11/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/alex/.local/lib/python3.11/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /home/alex/.local/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /home/alex/.local/lib/python3.11/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /home/alex/.local/lib/python3.11/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /home/alex/.local/lib/python3.11/site-packages (from torch) (2024.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/alex/.local/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/alex/.local/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/alex/.local/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/alex/.local/lib/python3.11/site-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/alex/.local/lib/python3.11/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/alex/.local/lib/python3.11/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/alex/.local/lib/python3.11/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/alex/.local/lib/python3.11/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/alex/.local/lib/python3.11/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/alex/.local/lib/python3.11/site-packages (from torch) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/alex/.local/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/alex/.local/lib/python3.11/site-packages (from torch) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/alex/.local/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.3.101)
# Requirement already satisfied: requests in /home/alex/.local/lib/python3.11/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/alex/.local/lib/python3.11/site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/alex/.local/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/alex/.local/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/alex/.local/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/alex/.local/lib/python3.11/site-packages (from ultralytics) (3.8.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/lib/python3/dist-packages (from ultralytics) (5.4.1)
# Requirement already satisfied: scipy>=1.4.1 in /home/alex/.local/lib/python3.11/site-packages (from ultralytics) (1.12.0)
# Requirement already satisfied: tqdm>=4.64.0 in /home/alex/.local/lib/python3.11/site-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: psutil in /home/alex/.local/lib/python3.11/site-packages (from ultralytics) (5.9.8)
# Requirement already satisfied: py-cpuinfo in /home/alex/.local/lib/python3.11/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in /home/alex/.local/lib/python3.11/site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: seaborn>=0.11.0 in /home/alex/.local/lib/python3.11/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/alex/.local/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/alex/.local/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/alex/.local/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/alex/.local/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/alex/.local/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.4.7)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/alex/.local/lib/python3.11/site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/alex/.local/lib/python3.11/site-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/alex/.local/lib/python3.11/site-packages (from requests->torchvision) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alex/.local/lib/python3.11/site-packages (from requests->torchvision) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/alex/.local/lib/python3.11/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /home/alex/.local/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# Using cache found in /home/alex/.cache/torch/hub/ultralytics_yolov5_master
# requirements: Ultralytics requirements ['gitpython>=3.1.30', 'setuptools>=65.5.1'] not found, attempting AutoUpdate...
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gitpython>=3.1.30 in /home/alex/.local/lib/python3.10/site-packages (3.1.42)
# Requirement already satisfied: setuptools>=65.5.1 in /home/alex/.local/lib/python3.10/site-packages (69.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/alex/.local/lib/python3.10/site-packages (from gitpython>=3.1.30) (4.0.11)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/alex/.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30) (5.0.1)
#
# requirements: AutoUpdate success ✅ 1.1s, installed 2 packages: ['gitpython>=3.1.30', 'setuptools>=65.5.1']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
# YOLOv5 🚀 2024-2-15 Python-3.11.0rc1 torch-2.2.0+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
# Images
# imgs = ['https://ultralytics.com/images/zidane.jpg']  # batch of images
imgs = ['circle_square.png']
imgs = ['https://ultralytics.com/images/zidane.jpg', 'circle_square.png', 'cross2.png', 'iq_images/iq01.png']

# Inference
results = model(imgs)

# Results
print(results.xyxy[0])  # img1 predictions (tensor)
print(results.pandas().xyxy[0])  # img1 predictions (pandas)
results.print()
results.show()
# Out:
# image 1/4: 720x1280 2 persons, 2 ties
# image 2/4: 96x94 (no detections)
# image 3/4: 110x110 (no detections)
# image 4/4: 873x682 1 bird
# Speed: 148.2ms pre-process, 159.4ms inference, 0.8ms NMS per image at shape (4, 3, 640, 640)
# tensor([[7.42897e+02, 4.79786e+01, 1.14114e+03, 7.16823e+02, 8.80724e-01, 0.00000e+00],
#         [4.42039e+02, 4.37350e+02, 4.96720e+02, 7.09883e+02, 6.87267e-01, 2.70000e+01],
#         [1.25215e+02, 1.93607e+02, 7.10841e+02, 7.13070e+02, 6.42233e-01, 0.00000e+00],
#         [9.82893e+02, 3.08405e+02, 1.02733e+03, 4.20230e+02, 2.63046e-01, 2.70000e+01]])
#          xmin        ymin         xmax        ymax  confidence  class    name
# 0  742.897095   47.978607  1141.142090  716.822876    0.880724      0  person
# 1  442.038971  437.349854   496.719574  709.882935    0.687267     27     tie
# 2  125.214966  193.606750   710.841370  713.070251    0.642233      0  person
# 3  982.893311  308.404541  1027.329590  420.230103    0.263046     27     tie
# <PIL.Image.Image image mode=RGB size=1280x720>
# <PIL.Image.Image image mode=RGB size=94x96>
# <PIL.Image.Image image mode=RGB size=110x110>
# <PIL.Image.Image image mode=RGB size=682x873>

# %%
results.pandas().xyxy[0]
# Out:
#          xmin        ymin         xmax        ymax  confidence  class    name
# 0  742.897095   47.978607  1141.142090  716.822876    0.880724      0  person
# 1  442.038971  437.349854   496.719574  709.882935    0.687267     27     tie
# 2  125.214966  193.606750   710.841370  713.070251    0.642233      0  person
# 3  982.893311  308.404541  1027.329590  420.230103    0.263046     27     tie
