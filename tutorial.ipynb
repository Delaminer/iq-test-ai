# %%
# %pip install pooch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pooch in /home/alex/.local/lib/python3.11/site-packages (1.8.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/alex/.local/lib/python3.11/site-packages (from pooch) (4.2.0)
# Requirement already satisfied: packaging>=20.0 in /home/alex/.local/lib/python3.11/site-packages (from pooch) (23.2)
# Requirement already satisfied: requests>=2.19.0 in /home/alex/.local/lib/python3.11/site-packages (from pooch) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/alex/.local/lib/python3.11/site-packages (from requests>=2.19.0->pooch) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/alex/.local/lib/python3.11/site-packages (from requests>=2.19.0->pooch) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/alex/.local/lib/python3.11/site-packages (from requests>=2.19.0->pooch) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alex/.local/lib/python3.11/site-packages (from requests>=2.19.0->pooch) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy.ndimage import shift
import matplotlib.pyplot as plt
from scipy import datasets
image = datasets.ascent()
print(image.shape)
image_shifted_vertically = shift(image, (20, 0))
image_shifted_both_directions = shift(image, (-200, 100))
fig, axes = plt.subplots(3, 1, figsize=(4, 12))
plt.gray()  # show the filtered result in grayscale
top, middle, bottom = axes
for ax in axes:
    ax.set_axis_off()  # remove coordinate system
top.imshow(image)
top.set_title("Original image")
middle.imshow(image_shifted_vertically)
middle.set_title("Vertically shifted image")
bottom.imshow(image_shifted_both_directions)
bottom.set_title("Image shifted in both directions")
fig.tight_layout()
# Out:
# (512, 512)
